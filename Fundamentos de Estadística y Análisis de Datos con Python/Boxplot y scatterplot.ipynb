# %%
import scipy.stats
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('bicicletas-compartidas.csv')

# %%
df.columns
# Out:
# Index(['fecha', 'bicis-compartidas', 'temp-obs', 'sens-temp', 'hum', 'viento',
#        'codigo-clima', 'festivo', 'findesemana', 'cuartil-ano'],
#       dtype='object')

# %%
y = df['bicis-compartidas']

# %%
fig, ax = plt.subplots()
ax.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f8829172b20>,
#   <matplotlib.lines.Line2D at 0x7f8829357760>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f8828e13670>,
#   <matplotlib.lines.Line2D at 0x7f8828fdbca0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f8829172070>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f8828fe66d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f8828fec0d0>],
#  'means': []}

# %%
sns.boxplot(x = 'cuartil-ano', y = 'bicis-compartidas', data = df)

# %%
from scipy.stats import gaussian_kde

xy = np.vstack([df['viento'], df['bicis-compartidas']])
z = gaussian_kde(xy)(xy)

fig, ax = plt.subplots()
ax.scatter(df['viento'], df['bicis-compartidas'], c = z)
ax.set_title('Distribucion conjunta de Viento y Bicis compartidas')
ax.set_xlabel('Viento')
ax.set_ylabel('Bicis compartidas')
# Out:
# Text(0, 0.5, 'Bicis compartidas')
